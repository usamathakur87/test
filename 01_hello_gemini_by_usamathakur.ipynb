# %% [markdown]
# <a href="https://colab.research.google.com/github/usamathakur87/test/blob/main/01_hello_gemini_by_usamathakur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.6 MB/s eta 0:00:00
# ...

# %%
import langchain_google_genai as genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
from google.colab import userdata
GOOGLE_API_KEY= userdata.get('GOOGLE_API_KEY')
# Out:
# 'AIzaSyClgNlOgoZ6T5ZaL8jYKF7kulZ9TR0f52A'

# %%
llm: ChatGoogleGenerativeAI = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",  # Specify the model to use
    api_key=GOOGLE_API_KEY,     # Provide the Google API key for authentication
    temperature=0.2,            # Set the randomness of the model's responses (0 = deterministic, 1 = very random)
)

# %%
response = model.invoke("say Hello World!")

# %%
print(response.content)
# Out:
# Hello World!
